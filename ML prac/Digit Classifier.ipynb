# %%
import network
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import mnist
from sklearn.model_selection import train_test_split

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %%
train_y = train_y.reshape(train_y.shape[0],1)
test_y = test_y.reshape(test_y.shape[0],1)
print('X_train: ' + str(train_X.shape))
print('Y_train: ' + str(train_y.shape))
print('X_test:  '  + str(test_X.shape))
print('Y_test:  '  + str(test_y.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000, 1)
# X_test:  (10000, 28, 28)
# Y_test:  (10000, 1)

# %%
for i in range(9):  
    plt.subplot(330 + 1 + i)
    plt.imshow(train_X[i], cmap=plt.get_cmap('gray'))

# %%
big = np.array([img.flatten() for img in train_X])
big.shape
# Out:
# (60000, 784)

# %%
boom = (train_y==0).astype('uint8')
for i in range(1,10):
    boom = np.hstack((boom,(train_y==i).astype('uint8')))
boom.shape[1]
# Out:
# 10

# %%
nn = network.NeuralNetwork((big.shape[1],16,16,boom.shape[1]))

# %%
nn.train(big,boom,100,100,0.2)
nn.plotProgress()
nn.cost(big,boom)
# Out:
# 0.09928617512074209
